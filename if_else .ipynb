# %% [markdown]
# #Q1. Write a program to calculate the electricity bill
# using only if statement? (accept number of unit from user)
# according to the following criteria:
#
# Unit Price
# First 100 units no charge
# Next 100 units Rs 5 per unit
# After 200 units Rs 10 per unit
# (For example, if input unit is 350 than total bill amount is Rs2000). Lets explain...
# For first 100 no charges
# Now you have 250 unit remaining
# 100-200 you need to pay – 100*5 = 500
# Now 200-100 you need to pay 150*10 = 1500
# Total = 500+1500 = 2000

# %% [markdown]
# # PROGRAM -1

# %%
UNIT  = int(input("ENTER THE NUMBER OF UNIT :"))
TOTAL BILL = 0
if UNIT <=100: 
 print("No Charge ")           #####doubt 
elif UNIT >100 
  UNIT=UNIT-100 
  TOTAL BILL = UNIT * 5
# Out:
# ENTER THE NUMBER OF UNIT : 1

# %% [markdown]
# # PROGRAM-2

# %%
PERCEN= int (input("Plz enter your percentage :"))
if (PERCEN >90 ):
    print(" YOUR GRADE IS A")
elif (PERCEN >80 and PERCEN <=90 ):
    print("YOUR GRADE IS B")
elif (PERCEN >=60 and PERCEN <=80 ):
    print("YOUR GRADE IS C")
else:
    print("YOUR GRADE IS D ")
# Out:
# Plz enter your percentage : 45
# YOUR GRADE IS D

# %% [markdown]
# # PROGRAM -3

# %%
a=int (input("Enter age of first person :"))
b=int (input("Enter age of scnd  person :"))
c=int (input("Enter age of third person :"))
d=int (input("Enter age of fourth person :"))
if (a<b and a<c and a<d):
 print ("A IS YOUNGER ")
elif(b<a and b<c and b<d):
 print("B IS YOUNGER ")
elif(c<a and c<b and c<d):
 print("C IS YOUNGER ")
else:
 print("D IS YOUNGER ")
# Out:
# Enter age of first person : 78
# Enter age of scnd  person : 56
# Enter age of third person : 1
# Enter age of fourth person : 0
# D IS YOUNGER

# %% [markdown]
# # PROGRAM -  4

# %%
year= int(input("Enter the working years in numbers :"))
salary= int(input("Enter your salary:"))
TOTAL=0
if (year > 10 ):
     print("Your bonus will be 10 percent")
     TOTAL= salary + 0.1*salary
     print("YOUR SALARY AFTER BONUS WILL BE :", TOTAL)
elif (year>=6  and year<= 10 ):
     print("Your bonus will be 8 percent")
     TOTAL= salary + 0.08*salary
     print("YOUR SALARY AFTER BONUS WILL BE :", TOTAL)
elif (year <=6):
     print("Your bonus will be 5 percent")
     TOTAL= salary + 0.06*salary
     print("YOUR SALARY AFTER BONUS WILL BE :", TOTAL)
# Out:
# Enter the working years in numbers : 6
# Enter your salary: 50000
# Your bonus will be 8 percent
# YOUR SALARY AFTER BONUS WILL BE : 54000.0

# %% [markdown]
# # PROGRAM -5

# %%
a=int(input("Enter first number :"))
b=int(input("Enter scnd number :"))
c=int(input("Enter third  number :"))
if a > b:
    if a < c:
        second = a
    else:
        if b > c:
            second = b
        else:
            second = c
else:
    if b < c:
        second = b
    else:
        if a > c:
            second = a
        else:
            second = c
print("Second largest number is:", second)
# Out:
# Enter first number : 23
# Enter scnd number : 78
# Enter third  number : 90
# Second largest number is: 78

# %% [markdown]
# # PROGRAM-6

# %%
MP=int(input("Enter the marked price :"))
if (MP > 10000):
        NET_AMOUNT= MP - 0.2* MP
        print("YOUR NET AMOUNT AFTER DISCOUNT IS :" ,NET_AMOUNT)
elif (MP > 7000 and MP <=10000):
        NET_AMOUNT= MP - 0.15*MP
        print("YOUR NET AMOUNT AFTER DISCOUNT IS :" ,NET_AMOUNT)
elif (MP <= 7000):
        NET_AMOUNT= MP - 0.1*MP
        print("YOUR NET AMOUNT AFTER DISCOUNT IS :", NET_AMOUNT)
# Out:
# Enter the marked price : 100
# YOUR NET AMOUNT AFTER DISCOUNT IS : 90.0

# %% [markdown]
# # PROGRAM -7

# %%
eng=int (input ("Enter ur eng marks :"))
math=int (input ("Enter ur math marks :"))
sci=int (input ("Enter ur sci marks :"))
sst=int (input ("Enter ur sst  marks :"))
if(eng> 80 and math > 80 and sci> 80 and  sst >80 ):
   print("you can opt for science ")
elif(eng>80 and math > 50 and sci >50 ):
   print("you can opt for commerce streams")
elif(eng >80 and sst> 80 ):
   print("you can opt for humanities")
else:
    print("No stream Allocated")
# Out:
# Enter ur eng marks : 90
# Enter ur math marks : 90
# Enter ur sci marks : 90
# Enter ur sst  marks : 90
# you can opt for science

# %% [markdown]
# # PROGRAM- 8

# %%
n= int(input("Enter number:"))
if (n%5==0):
    print("hello")
else:
    print("bye")
# Out:
# Enter number: 90
# hello

# %% [markdown]
# # PROGRAM-9

# %%
num = int(input("Enter a number: "))
last_digit = num % 10
if last_digit % 3 == 0:
    print("Last digit is divisible by 3")
else:
    print("Last digit is NOT divisible by 3")
# Out:
# Enter a number:  78
# Last digit is NOT divisible by 3

# %% [markdown]
# # PROGRAM 10

# %%
num = int(input("Enter a number: "))
if num >= 100 and num <= 999:
    print("It is a three-digit number")
else:
    print("It is NOT a three-digit number")
# Out:
# Enter a number:  8769
# It is NOT a three-digit number
